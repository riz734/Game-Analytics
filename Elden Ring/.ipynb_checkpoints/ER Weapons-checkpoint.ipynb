# %%
import pandas as pd
import os
import re

# %%
#This function takes is a string (name of item,npc,location,weapon,etc) and returns the dataframe where it is located
#Example: Passing in "Giant Bat" will return the creatures.csv dataframe, passing in a weapon name will return the weapons.csv dataframe and so on


def find_dataset(name):
    arr = os.listdir('data/')
    
    for i in range(len(arr)):
        
        if ".csv" in arr[i]:
            df = pd.read_csv("data/" +arr[i])
            
            for value in df["name"]:
                
                if name.lower() in value.lower():
                    return df
            else:
                return "No matching "
                
#This function uses find_dataset to grab the dataframe of the passed in string, then returns the row where the string matches
def search(search_string):  
    df = find_dataset(search_string)
    return df[df["name"]==search_string]

#This function takes in a type of data and returns the entire frame
#Example: Passing "armors" will return the entire armors.csv dataframe
def sets(type_str):
        
    df = pd.read_csv("data/" + type_str+ ".csv")
    
    return df

# %%
def parse_atk_def(df,atk_or_def):

    print(df.iloc[6])
    #takes in row passed in from weapons_df
    #loops through df["attack"], matches and saves type of dmg in list
    for i in df.iloc[atk_or_def]:
        types = re.findall(r"(?:[A-Z][a-z]+)", i)
    
    #loops through df["attack"], matches and saves amount of dmg in list
    for k in df.iloc[atk_or_def]:
        dmg = re.findall(r"(?:\d+)", k)
    
    for atk_type in range(len(types)):            
        
        #adds "_atk" or "_def" to all values in list
        if atk_or_def == 4:
            lists = [[s + "_atk" for s in types], dmg]
        elif atk_or_def == 5:
            lists = [[s + "_def" for s in types], dmg]
            
        #concats the types and dmg dataframes, transposes to flat format
        df = df.reset_index(drop=True)
        df = pd.concat([pd.Series(x) for x in lists], axis=1)
        df = df.T

        df = df.rename(columns=df.iloc[0])[1:]
        return df
    
def create_atk_def(df,atk_or_def):
    #create empty df to append to
    new_df = pd.DataFrame()
    #iterating through rows in the weapons_df
    for row in df.iterrows():
        
        #apply parse_atk function to row, append returning df of attack type + dmg amount to empty df
        current_row = row[1].to_frame()
        #print(current_row)
        new_df = new_df.append(parse_atk_def(current_row,atk_or_def))
    #print(atk(row[1].to_frame()))
    #drops empty nan
    try:
        new_df = new_df.drop(columns=[float("nan")])
        return new_df.reset_index(drop=True)
    except:
        return new_df.reset_index(drop=True)

# %%
def parse_scaling(df):
    #takes in row passed in from weapons_df
    #loops through df["scalesWith"], matches and saves scaling in list
    #print(df)
    scales_with = []
    for i in df["scalesWith"]:
        #print(i)
        scales_with.append(re.findall(r"(?:[A-Z][a-z][a-z])", i))
    #print(scales_with)
    #loops through df["scalesWith"], matches and saves scalings in list
    clean_scalings = []
    for k in df["scalesWith"]:
        clean_scalings.append(re.findall(r"(?:[A-E])\'", k))

    return (scales_with,clean_scalings)

def add_scaling(df):
    scale = parse_scaling(df)

    scale_with = scale[0]
    scaling_rate = scale[1]
    #df["scalesWith"] = "0"
    df["scalesWith"] = scale_with
    df["scalingRate"] = scaling_rate
    return df

# %%
def parse_attributes(df):
    
    #drops dupicate columns
    df = df.loc[:,~df.columns.duplicated()].copy()
    
    #takes in row passed in from weapons_df
    #loops through df["scalesWith"], matches and saves scaling in list
    #print(df)
    attr = []
    for i in df["requiredAttributes"]:
        #print(i)
        attr.append(re.findall(r"(?:[A-Z][a-z][a-z])", i))
    #print(scales_with)
    #loops through df["scalesWith"], matches and saves scalings in list
    amount = []
    for k in df["requiredAttributes"]:
        amount.append(re.findall(r"(?:\d+)", k))

    return (attr,amount)

def add_attributes(df):
    parse = parse_attributes(df)

    attributes = parse[0]
    amount = parse[1]
    #df["scalesWith"] = "0"
    df["attributes"] = attributes
    df["attr_pnts_req"] = amount
    return df

# %%
def merge_dfs(df):
    return pd.concat([df, create_atk_def(df,4), create_atk_def(df,5), add_scaling(df),add_attributes(df)], axis=1)

weapons_df = merge_dfs(sets("weapons"))
weapons_df = weapons_df.loc[:,~weapons_df.columns.duplicated()].copy()
# Out:
# 0    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 1    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 2    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 3    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 4    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 5    [{'name': 'Arc', 'scaling': 'A'}]
# Name: scalesWith, dtype: object
# 6    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 7    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 8    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 9    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 10    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 11    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 12    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 13    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 14    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 15    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 16    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 17    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 18    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 19    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 20    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 21    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 22    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 23    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 24    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 25    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 26    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 27    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 28    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 29    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 30    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 31    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 32    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 33    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 34    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 35    [{'name': 'Str', 'scaling': 'B'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 36    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 37    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 38    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 39    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 40    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 41    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 42    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 43    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 44    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 45    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 46    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 47    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 48    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 49    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 50    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 51    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 52    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 53    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 54    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 55    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 56    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 57    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 58    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 59    [{'name': '', 'scaling': '-'}]
# Name: scalesWith, dtype: object
# 60    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 61    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 62    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 63    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 64    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 65    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 66    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 67    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 68    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 69    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 70    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 71    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 72    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 73    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 74    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 75    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 76    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 77    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 78    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 79    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 80    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 81    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 82    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 83    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 84    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 85    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 86    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 87    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 88    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 89    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 90    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 91    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 92    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 93    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 94    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 95    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 96    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 97    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 98    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 99    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 100    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 101    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 102    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 103    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 104    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 105    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 106    [{'name': 'Fai', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 107    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 108    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 109    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 110    [{'name': 'STR', 'scaling': 'E'}, {'name': 'DE...
# Name: scalesWith, dtype: object
# 111    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 112    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 113    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 114    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 115    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 116    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 117    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 118    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 119    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 120    [{'name': 'Str', 'scaling': '?'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 121    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 122    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 123    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 124    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 125    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 126    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 127    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 128    [{'name': 'Str', 'scaling': 'D'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 129    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 130    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 131    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 132    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 133    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 134    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 135    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 136    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 137    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 138    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 139    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 140    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 141    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 142    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 143    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 144    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 145    [{'name': 'Str', 'scaling': 'D'}, {'name': 'Ar...
# Name: scalesWith, dtype: object
# 146    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 147    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 148    [{'name': 'Str', 'scaling': 'B'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 149    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 150    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 151    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 152    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 153    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 154    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 155    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 156    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 157    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 158    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 159    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 160    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 161    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 162    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 163    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 164    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 165    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 166    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 167    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 168    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 169    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 170    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 171    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 172    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 173    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 174    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 175    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 176    [{'name': 'Arc', 'scaling': 'B'}]
# Name: scalesWith, dtype: object
# 177    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 178    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 179    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 180    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 181    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 182    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 183    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 184    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 185    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 186    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 187    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 188    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 189    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 190    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 191    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 192    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 193    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 194    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 195    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 196    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 197    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 198    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 199    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 200    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 201    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 202    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 203    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 204    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 205    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 206    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 207    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 208    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 209    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 210    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 211    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 212    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 213    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 214    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 215    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 216    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 217    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 218    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 219    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 220    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 221    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 222    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 223    [{'name': 'Str', 'scaling': 'E'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 224    [{'name': 'Str', 'scaling': 'E'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 225    [{'name': 'Str', 'scaling': 'E'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 226    [{'name': 'Str', 'scaling': 'D'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 227    [{'name': 'Int', 'scaling': 'D'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 228    [{'name': 'Fai', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 229    [{'name': 'Fai', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 230    [{'name': 'Fai', 'scaling': 'D'}, {'name': 'Ar...
# Name: scalesWith, dtype: object
# 231    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 232    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 233    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 234    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 235    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 236    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 237    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 238    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 239    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 240    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 241    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 242    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 243    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 244    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 245    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 246    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 247    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 248    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 249    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 250    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 251    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 252    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 253    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 254    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 255    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 256    [{'name': 'Fai', 'scaling': 'B'}]
# Name: scalesWith, dtype: object
# 257    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 258    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 259    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 260    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 261    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 262    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 263    [{'name': 'Str', 'scaling': 'E'}]
# Name: scalesWith, dtype: object
# 264    [{'name': 'Str', 'scaling': 'E'}]
# Name: scalesWith, dtype: object
# 265    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 266    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 267    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 268    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 269    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 270    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 271    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 272    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 273    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 274    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 275    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 276    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 277    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 278    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 279    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 280    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 281    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 282    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 283    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 284    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 285    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 286    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 287    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 288    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 289    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 290    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 291    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 292    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 293    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 294    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 295    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 296    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 297    [{'name': 'Str', 'scaling': 'D'}, {'name': 'DE...
# Name: scalesWith, dtype: object
# 298    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 299    [{'name': 'Str', 'scaling': 'B'}]
# Name: scalesWith, dtype: object
# 300    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 301    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 302    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 303    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 304    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 305    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 306    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 0    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 1    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 2    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 3    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 4    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 5    [{'name': 'Arc', 'scaling': 'A'}]
# Name: scalesWith, dtype: object
# 6    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 7    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 8    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 9    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 10    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 11    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 12    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 13    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 14    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 15    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 16    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 17    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 18    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 19    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 20    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 21    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 22    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 23    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 24    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 25    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 26    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 27    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 28    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 29    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 30    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 31    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 32    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 33    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 34    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 35    [{'name': 'Str', 'scaling': 'B'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 36    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 37    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 38    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 39    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 40    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 41    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 42    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 43    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 44    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 45    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 46    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 47    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 48    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 49    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 50    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 51    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 52    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 53    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 54    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 55    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 56    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 57    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 58    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 59    [{'name': '', 'scaling': '-'}]
# Name: scalesWith, dtype: object
# 60    [{'name': '-'}]
# Name: scalesWith, dtype: object
# 61    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 62    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 63    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 64    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 65    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 66    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 67    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 68    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 69    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 70    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 71    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 72    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 73    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 74    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 75    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 76    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 77    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 78    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 79    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 80    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 81    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 82    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 83    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 84    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 85    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 86    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 87    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 88    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 89    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 90    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 91    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 92    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 93    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 94    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 95    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 96    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 97    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 98    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 99    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 100    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 101    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 102    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 103    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 104    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 105    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 106    [{'name': 'Fai', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 107    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 108    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 109    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 110    [{'name': 'STR', 'scaling': 'E'}, {'name': 'DE...
# Name: scalesWith, dtype: object
# 111    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 112    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 113    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 114    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 115    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 116    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 117    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 118    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 119    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 120    [{'name': 'Str', 'scaling': '?'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 121    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 122    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 123    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 124    [{'name': 'Str', 'scaling': 'E'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 125    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 126    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 127    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 128    [{'name': 'Str', 'scaling': 'D'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 129    [{'name': 'Str', 'scaling': 'D'}, {'name': 'In...
# Name: scalesWith, dtype: object
# 130    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 131    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 132    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 133    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 134    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 135    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 136    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 137    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 138    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 139    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 140    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 141    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 142    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 143    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 144    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 145    [{'name': 'Str', 'scaling': 'D'}, {'name': 'Ar...
# Name: scalesWith, dtype: object
# 146    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 147    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 148    [{'name': 'Str', 'scaling': 'B'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 149    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 150    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 151    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 152    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 153    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 154    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 155    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 156    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 157    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 158    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 159    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 160    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 161    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 162    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 163    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 164    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 165    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 166    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 167    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 168    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 169    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 170    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 171    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 172    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 173    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 174    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 175    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 176    [{'name': 'Arc', 'scaling': 'B'}]
# Name: scalesWith, dtype: object
# 177    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 178    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 179    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 180    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 181    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 182    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 183    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 184    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 185    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 186    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 187    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 188    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 189    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 190    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 191    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 192    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 193    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 194    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 195    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 196    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 197    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 198    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 199    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 200    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 201    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 202    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 203    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 204    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 205    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 206    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 207    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 208    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 209    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 210    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 211    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 212    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 213    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 214    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 215    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 216    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 217    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 218    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 219    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 220    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 221    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 222    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 223    [{'name': 'Str', 'scaling': 'E'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 224    [{'name': 'Str', 'scaling': 'E'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 225    [{'name': 'Str', 'scaling': 'E'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 226    [{'name': 'Str', 'scaling': 'D'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 227    [{'name': 'Int', 'scaling': 'D'}, {'name': 'Fa...
# Name: scalesWith, dtype: object
# 228    [{'name': 'Fai', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 229    [{'name': 'Fai', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 230    [{'name': 'Fai', 'scaling': 'D'}, {'name': 'Ar...
# Name: scalesWith, dtype: object
# 231    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 232    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 233    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 234    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 235    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 236    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 237    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 238    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 239    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 240    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 241    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 242    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 243    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 244    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 245    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 246    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 247    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 248    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 249    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 250    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 251    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 252    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 253    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 254    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 255    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 256    [{'name': 'Fai', 'scaling': 'B'}]
# Name: scalesWith, dtype: object
# 257    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 258    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 259    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 260    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 261    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 262    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 263    [{'name': 'Str', 'scaling': 'E'}]
# Name: scalesWith, dtype: object
# 264    [{'name': 'Str', 'scaling': 'E'}]
# Name: scalesWith, dtype: object
# 265    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 266    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 267    [{'name': 'Str', 'scaling': 'D'}]
# Name: scalesWith, dtype: object
# 268    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 269    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 270    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 271    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 272    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 273    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 274    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 275    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 276    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 277    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 278    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 279    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 280    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 281    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 282    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 283    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 284    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 285    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 286    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 287    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 288    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 289    [{'name': 'Str', 'scaling': 'C'}]
# Name: scalesWith, dtype: object
# 290    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 291    [{'name': 'Str', 'scaling': '?'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 292    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 293    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 294    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 295    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 296    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 297    [{'name': 'Str', 'scaling': 'D'}, {'name': 'DE...
# Name: scalesWith, dtype: object
# 298    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 299    [{'name': 'Str', 'scaling': 'B'}]
# Name: scalesWith, dtype: object
# 300    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 301    [{'name': 'Str', 'scaling': 'C'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 302    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 303    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 304    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 305    [{'name': 'Str', 'scaling': 'D'}, {'name': 'De...
# Name: scalesWith, dtype: object
# 306    [{'name': 'Str', 'scaling': 'E'}, {'name': 'De...
# Name: scalesWith, dtype: object

# %%
weapons_df.columns
# Out:
# Index(['id', 'name', 'image', 'description', 'attack', 'defence', 'scalesWith',
#        'requiredAttributes', 'category', 'weight', 'scalingRate', 'attributes',
#        'attr_pnts_req', 'Phy_atk', 'Mag_atk', 'Fire_atk', 'Ligt_atk',
#        'Holy_atk', 'Crit_atk', 'Rng_atk', 'Sor_atk', 'Inc_atk', 'Sorc_atk',
#        'Light_atk', 'Phy_def', 'Mag_def', 'Fire_def', 'Ligt_def', 'Holy_def',
#        'Boost_def'],
#       dtype='object')

# %%
weapons_df = weapons_df.drop(columns=[])
